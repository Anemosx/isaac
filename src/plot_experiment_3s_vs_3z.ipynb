# %%
from dotmap import DotMap
import json
import pandas as pd
import numpy as np
import matplotlib.patches as mpatches
import seaborn as sns
import matplotlib.pyplot as plt
import neptune.new as neptune
import os
import datetime

"""
High quality plots for evaluation.

author(s): Arnold Unterauer
"""




###########################
# qtran

tr_ratio_1_old = [576, 577, 578, 579, 580]
tr_ratio_10_old = [601, 602, 603, 604, 605]
tr_ratio_15_old = [606, 607, 608, 609, 610]
tr_ratio_15_obvious = [611, 612, 613, 614, 615]
tr_ratio_15_sim = [616, 617, 618, 619, 620]
tr_ratio_15_sim_obvious = [621, 622, 623, 624, 625]
tr_ratio_15_after_sim = [650, 651, 652, 653, 654]
tr_ratio_15_after_obvious_sim = [655, 656, 657, 658, 659]
tr_ratio_15_after_sim_obvious = [660, 661, 662, 663, 664]
tr_ratio_15_after_obvious_sim_obvious = [665, 666, 667, 668, 669]

label_0_0 = [696, 697, 698, 699, 700]
label_0_1 = [701, 702, 703, 704, 705]
label_0_5 = [706, 707, 708, 709, 710]
label_1_0 = [711, 712, 713, 714, 715]
label_5_0 = [716, 717, 718, 719, 720]
label_inf = [721, 722, 723, 724, 725]
obvious = [726, 727, 728, 729, 730]
# random = [731, 732, 733, 734, 735]

imitation = [746, 747, 748, 749, 750]

tr_ratio_1 = [781, 782, 783, 784, 785]
tr_ratio_5 = [756, 757, 758, 759, 760]
tr_ratio_8 = [766, 767, 768, 769, 770]
tr_ratio_10 = [761, 762, 763, 764, 765]
tr_ratio_15 = [696, 697, 698, 699, 700]
tr_ratio_20 = [771, 772, 773, 774, 775]

history_normal = [1200, 1201, 1202, 1203, 1204]
history_obs_pos = [1195, 1196, 1197, 1198, 1199]
history_state = [1190, 1191, 1192, 1193, 1194]
history_pos = [1185, 1186, 1187, 1188, 1189]

optim_sgd = [1155, 1156, 1157, 1158, 1159]
optim_adam = [1150, 1151, 1152, 1153, 1154]
optim_rmsprop = [1165, 1166, 1167, 1168, 1169]

without = [1205, 1206, 1207, 1208, 1209]
indi_pos = [1220, 1221, 1222, 1223, 1224]
anomaly_step = [1215, 1216, 1217, 1218, 1219]
obvious_without = [1210, 1211, 1212, 1213, 1214]

anomaly_step1 = [1295, 1296, 1297, 1298, 1299]
indi_pos1 = [1290, 1291, 1292, 1293, 1294]
obvious1 = [1285, 1286, 1287, 1288, 1289]

anomaly_step_with_tr_ratio_5 = [1302, 1303, 1304, 1305, 1306]
anomaly_step_every_5 = [1307, 1308, 1309, 1310, 1311]
anomaly_step_every_10 = [1312, 1313, 1314, 1315, 1316]

# algo_qtran = [1317, 1318, 1319, 1320, 1321]
# algo_qmix = [1322, 1323, 1324, 1325, 1326]
# algo_qplex = [1327, 1328, 1329, 1330, 1331]
# algo_vdn = [1332, 1333, 1334, 1335, 1336]
# algo_qmix_history = [1337, 1338, 1339, 1340, 1341]
# algo_ow_qmix = [1342, 1343, 1344, 1345, 1346]
# algo_ddpg = [1348, 1349, 1350, 1351, 1352]
# algo_ow_qmix_history = [1353, 1354, 1355, 1356, 1357]
# algo_iql = [1358, 1359, 1360, 1361, 1362]

qmix_hidden = [1363, 1364, 1365, 1366, 1367]
vdn_hidden = [1368, 1369, 1370, 1371, 1372]
qmix_history_hidden = [1373, 1374, 1375, 1376, 1377]
qtran_random = [1379, 1380, 1381, 1382, 1383]
qtran_hidden_c87bfd73 = [1386, 1387, 1388, 1389, 1390]
qtran_hidden_c0900063 = [1391, 1392, 1393, 1394, 1395]

qmix_hidden_6671c021 = [1397, 1398, 1399, 1400, 1401]
qmix_random = [1402, 1403, 1404, 1405, 1406]

qtran_hidden_05040b72 = [1407, 1408, 1409, 1410, 1411]
qtran_hidden_ad6f7008_tr_20 = [1412, 1413, 1414, 1415, 1416]
qtran_hidden_e71c5c89_tr_20_step_20 = [1417, 1418, 1419, 1420, 1421]

qtran_hidden_e71c5c89_tr_10_step_3 = [1429, 1430, 1431, 1432, 1433]
qtran_hidden_e71c5c89_tr_10_step_5 = [1434, 1435, 1436, 1437, 1438]
qtran_hidden_e71c5c89_tr_10_step_10 = [1439, 1440, 1441, 1442, 1443]

qtran_hidden_tmax_e71c5c89_tr_10_step_5 = [1444, 1445, 1446, 1447, 1448]
qtran_hidden_tmax_e71c5c89_tr_10_indi_0 = [1449, 1450, 1451, 1452, 1453]
qtran_hidden_tmax_e71c5c89_tr_10_step_1 = [1454, 1455, 1456, 1457, 1458]

qtran_weight_directories_tr_15 = [1465, 1466, 1467, 1468, 1469]
qtran_step_reward_tr_15_0_01 = [1470, 1471, 1472, 1473, 1474]
qtran_step_reward_tr_15_0_05 = [1475, 1476, 1477, 1478, 1479]

qtran_step_reward_tr_10_0_2 = [1480, 1481, 1482, 1483, 1484]
qtran_step_reward_tr_5_0_2 = [1485, 1486, 1487, 1488, 1489]
qtran_step_reward_tr_10_0_1 = [1490, 1491, 1492, 1493, 1494]

eval_5_qmix = [1495, 1496, 1498, 1499, 1510]
eval_5_vdn = [1500, 1501, 1502, 1503, 1504]
eval_5_iql = [1505, 1506, 1507, 1508, 1509]
eval_5_qplex = [1511, 1512, 1513, 1514, 1515]
eval_5_ow_qmix = [1521, 1522, 1523, 1524, 1525]
eval_5_qtran = [1526, 1527, 1528, 1529, 1530]

eval_5_qtran_random = [1531, 1532, 1533, 1534, 1535]
eval_5_vdn_random = [1536, 1537, 1538, 1539, 1540]
eval_5_qplex_random = [1541, 1542, 1543, 1544, 1545]
eval_5_qmix_random = [1546, 1547, 1548, 1549, 1550]
eval_5_ow_qmix_random = [1551, 1552, 1553, 1554, 1555]
eval_5_iql_random = [1556, 1557, 1558, 1559, 1560]

batch_size_64_qmix = [1581, 1582, 1583, 1584, 1585]
batch_size_64_qtran_tr_5 = [1596, 1597, 1598, 1599, 1600]
batch_size_64_qtran_tr_20 = [1601, 1602, 1603, 1604, 1605]

qtran_agent_eval = [1676, 1677, 1678, 1679, 1680]
qtran_agent_eval_obvious = [1681, 1682, 1683, 1684, 1685]
qtran_obvious = [1686, 1687, 1688, 1689, 1690]

box_plot_qmix_hidden = [1831, 1832, 1833, 1834, 1835]
box_plot_vdn_hidden = [1836, 1837, 1838, 1839, 1840]
box_plot_iql_hidden = [1841, 1842, 1843, 1844, 1845]
box_plot_qplex_hidden = [1846, 1847, 1848, 1849, 1850]
box_plot_ow_qmix_hidden = [1851, 1852, 1853, 1854, 1855]
box_plot_qtran_hidden = [1856, 1857, 1858, 1859, 1860]

box_plot_qmix_random = [1861, 1862, 1863, 1864, 1865]
box_plot_vdn_random = [1866, 1867, 1868, 1869, 1870]
box_plot_iql_random = [1871, 1872, 1873, 1874, 1875]
box_plot_qplex_random = [1876, 1877, 1878, 1879, 1880]
box_plot_ow_qmix_random = [1881, 1882, 1883, 1884, 1885]
box_plot_qtran_random = [1886, 1887, 1888, 1889, 1890]

box_plot_qmix_algo = [1906, 1907, 1908, 1909, 1910]
box_plot_vdn_algo = [1911, 1912, 1913, 1914, 1915]
box_plot_iql_algo = [1916, 1917, 1918, 1919, 1920]
box_plot_qplex_algo = [1921, 1922, 1923, 1924, 1925]
box_plot_ow_qmix_algo = [1926, 1927, 1928, 1929, 1932]
box_plot_qtran_algo = [1931, 1933, 1934, 1935, 1936]

qtran_5_with_act_comp = [1891, 1892, 1893, 1894, 1895]

obvious_qtran_old = [1896, 1897, 1898, 1899, 1900]
obvious_qmix_old = [1901, 1902, 1903, 1904, 1905]
obvious_vdn_old = [1937, 1938, 1939, 1940, 1941]
obvious_iql_old = [1942, 1943, 1944, 1945, 1946]
obvious_qplex_old = [1947, 1948, 1949, 1950, 1951]
obvious_ow_qmix_old = [1952, 1953, 1954, 1955, 1956]


box_obvious_ow_qmix = [1957, 1958, 1959, 1960, 1961]
box_obvious_qplex = [1962, 1963, 1964, 1965, 1966]
box_obvious_iql = [1967, 1968, 1969, 1970, 1971]
box_obvious_vdn = [1972, 1973, 1974, 1975, 1976]
box_obvious_qmix = [1977, 1978, 1979, 1980, 1981]
box_obvious_qtran = [1982, 1983, 1984, 1985, 1986]

box_hidden_qmix = [1987, 1988, 1989, 1990, 1991]
box_hidden_vdn = [1992, 1993, 1994, 1995, 1996]
box_hidden_iql = [1997, 1998, 1999, 2000, 2001]
box_hidden_qplex = [2002, 2003, 2004, 2005, 2006]
box_hidden_ow_qmix = [2007, 2008, 2009, 2010, 2011]
box_hidden_qtran = [2012, 2013, 2014, 2015, 2016]

box_random_qmix = [2017, 2018, 2019, 2020, 2021]
box_random_vdn = [2022, 2023, 2024, 2025, 2026]
box_random_iql = [2027, 2028, 2029, 2030, 2031]
box_random_qplex = [2032, 2033, 2034, 2035, 2036]
box_random_ow_qmix = [2037, 2038, 2039, 2040, 2041]
box_random_qtran = [2042, 2043, 2044, 2045, 2046]

hidden_qtran_uncomplete = [2187, 2188, 2189, 2190, 2191]







algo_qtran = [1317, 1318, 1319, 1320, 1321]
algo_qmix = [1322, 1323, 1324, 1325, 1326]
algo_qplex = [1327, 1328, 1329, 1330, 1331]
algo_vdn = [1332, 1333, 1334, 1335, 1336]
algo_iql = [1358, 1359, 1360, 1361, 1362]
algo_ow_qmix = [1342, 1343, 1344, 1345, 1346]

hidden_qtran = [2202, 2203, 2204, 2205, 2206]
hidden_qmix = [2192, 2193, 2194, 2195, 2196]
hidden_qplex = [2197, 2198, 2199, 2200, 2201]
hidden_vdn = [2207, 2208, 2209, 2210, 2211]
hidden_iql = [2212, 2213, 2214, 2215, 2216]
hidden_ow_qmix = [2217, 2218, 2219, 2220, 2221]

obvious_qtran = [2222, 2223, 2224, 2225, 2226]
obvious_qmix = [2227, 2228, 2229, 2230, 2231]
obvious_qplex = [2232, 2233, 2234, 2235, 2236]
obvious_vdn = [2269, 2270, 2271, 2272, 2273]
obvious_iql = [2274, 2275, 2276, 2277, 2278]
obvious_ow_qmix = [2279, 2280, 2281, 2282, 2283]

random_qtran = [2380, 2381, 2382, 2383, 2384]
random_qmix = [2385, 2386, 2387, 2388, 2389]
random_qplex = [2390, 2391, 2392, 2393, 2394]
random_vdn = [2414, 2415, 2416, 2417, 2418]
random_iql = [2419, 2420, 2421, 2422, 2423]
random_ow_qmix = [2424, 2425, 2426, 2427, 2428]















h_qtran = [2678, 2679, 2680, 2681, 2682]
h_qmix = [2683, 2684, 2685, 2686, 2687]
h_qplex = [2689, 2690, 2691, 2692, 2693]
h_vdn = [2694, 2695, 2696, 2697, 2698]
h_iql = [2699, 2700, 2701, 2702, 2703]
h_ow_qmix = [2704, 2705, 2706, 2707, 2708]

obv_qtran = [2715, 2716, 2717, 2718, 2719]
obv_qmix = [2720, 2721, 2722, 2723, 2724]
obv_qplex = [2725, 2726, 2740, 2728, 2729]
obv_vdn = [2730, 2731, 2732, 2733, 2734]
obv_iql = [2735, 2736, 2737, 2738, 2739]
obv_ow_qmix = [2741, 2742, 2743, 2744, 2745]







algo_qtran_eval = [2524, 2525, 2526, 2527, 2528]
algo_qmix_eval = [2529, 2530, 2531, 2532, 2533]
algo_qplex_eval = [2534, 2535, 2536, 2537, 2538]
algo_vdn_eval = [2539, 2540, 2541, 2542, 2543]
algo_iql_eval = [2544, 2545, 2546, 2547, 2548]
algo_ow_qmix_eval = [2549, 2550, 2551, 2552, 2553]

h_qtran_eval = [2797, 2798, 2799, 2800, 2801]
h_qmix_eval = [2802, 2803, 2804, 2805, 2806]
h_qplex_eval = [2807, 2808, 2809, 2810, 2811]
h_vdn_eval = [2812, 2813, 2814, 2815, 2816]
h_iql_eval = [2817, 2818, 2819, 2820, 2821]
h_ow_qmix_eval = [2822, 2823, 2824, 2825, 2826]

obv_qtran_eval = [2827, 2828, 2829, 2830, 2831]
obv_qmix_eval = [2832, 2833, 2834, 2835, 2836]
obv_qplex_eval = [2837, 2838, 2839, 2840, 2841]
obv_vdn_eval = [2842, 2843, 2844, 2845, 2846]
obv_iql_eval = [2847, 2848, 2849, 2850, 2851]
obv_ow_qmix_eval = [2852, 2853, 2854, 2855, 2856]

random_qtran_eval = [3147, 3148, 3149, 3150, 3151]
random_qmix_eval = [3152, 3153, 3154, 3155, 3156]
random_qplex_eval = [3157, 3158, 3159, 3160, 3161]
random_vdn_eval = [3162, 3163, 3164, 3165, 3166]
random_iql_eval = [3167, 3168, 3169, 3170, 3171]
random_ow_qmix_eval = [3172, 3173, 3174, 3175, 3176]







qtran_without_state = [3187, 3188, 3189, 3190, 3191]



titel = ""

runs = [algo_qtran, algo_qmix, algo_qplex, algo_vdn, algo_iql, algo_ow_qmix]

# runs = [obv_qtran, obv_qmix, obv_qplex, obv_vdn, obv_iql, obv_ow_qmix]
# runs = [h_qtran, h_qmix, h_qplex, h_vdn, h_iql, h_ow_qmix]
labels = ["QTRAN", "QMIX", "QPLEX", "VDN", "IQL", "OW-QMIX"]


# runs = [algo_qtran, h_qtran, random_qtran, obv_qtran]
# labels = ["No Substitution", "Hidden Attacker", "Random Agent", "Obvious Attacker"]



# titel = "3s_vs_3z Obvious Attacker Training"
#
# runs = [obv_qtran, obv_qmix, obv_qplex, obv_vdn, obv_iql, obv_ow_qmix]
# labels = ["QTRAN", "QMIX", "QPLEX", "VDN", "IQL", "OW-QMIX"]







# runs = [hidden_qtran, hidden_qmix, hidden_qplex]
# labels = ["EVAL", "QTRAN", "sef"]

# runs = [eval_5_ow_qmix, eval_5_ow_qmix_random]
# labels = ["Hidden Attacker", "Random Agent"]

# runs = [algo_qmix, algo_vdn, algo_iql, algo_qplex, algo_ow_qmix, algo_qtran]
# labels = ["QMIX", "VDN", "IQL", "QPLEX", "OW-QMIX", "QTRAN"]

# runs = [eval_5_qmix, eval_5_vdn, eval_5_iql, eval_5_qplex, eval_5_ow_qmix, eval_5_qtran]
# labels = ["QMIX", "VDN", "IQL", "QPLEX", "OW-QMIX", "QTRAN"]

# runs = [anomaly_step, anomaly_step_every_5, anomaly_step_every_10]
# labels = ["1", "5", "10"]

# runs = [without, indi_pos1, anomaly_step1, obvious1]
# labels = ["Vanilla", "Neighborhood", "Classifier", "Obvious"]

# runs = [without, indi_pos, anomaly_step, obvious_without]
# labels = ["Vanilla", "Neighborhood", "Classifier", "Obvious"]

# runs = [optim_rmsprop, optim_adam, optim_sgd]
# labels = ["RMSprop", "Adam", "SGD"]

# runs = [history_normal, history_state, history_pos, history_obs_pos]
# labels = ["observation", "state", "state pos", "obs rel pos"]

# runs = [tr_ratio_15_after_sim_obvious, tr_ratio_15_after_obvious_sim_obvious]
# labels = ["hidden", "obvious"]

# runs = [tr_ratio_1, tr_ratio_5, tr_ratio_8, tr_ratio_10, tr_ratio_15, tr_ratio_20]
# labels = ["ratio 1:1", "ratio 1:5", "ratio 1:8", "ratio 1:10", "ratio 1:15", "ratio 1:20"]

# runs = [label_0_0, label_0_1, label_0_5, label_1_0, label_5_0, label_inf]
# labels = ["threshold 0.0", "threshold 0.1", "threshold 0.5", "threshold 1.0", "threshold 5.0", "threshold inf"]

# only_ant = [358, 359, 360, 361, 362]
# only_mimic = [363, 364, 365, 366, 367]
# split_ant_before = [374, 375, 376, 377, 378]
# sim_train = [381, 382, 383, 384, 385]
# sim_train_only_ant = [386, 387, 388, 389, 390]
#
# hidden = [410, 411, 412, 413, 414]
# hidden_split = [415, 416, 417, 418, 419]
#
# qtran = [292, 296, 297, 298, 299]
#
# ignore_reward_in_label = [430, 431, 432, 433, 434]
#
# weight_label_only_gan = [425, 426, 427, 428, 429]
#
# weight_label = [420, 421, 422, 423, 424]
#
# runs = [hidden, hidden_split, weight_label, weight_label_only_gan, ignore_reward_in_label, only_ant, only_mimic]
# labels = ["Hidden", "Hidden consecutively", "Label weighted", "Label weighted only GAN", "Ignore rewards in label", "Obvious", "Imitation"]

# runs = [hidden, hidden_split, only_mimic]
# labels = ["Hidden Agents", "Hidden loss consecutively", "Only imitation"]



legend_location = "upper left"

# plot_types = ["return", "win", "accuracy_train_total", "accuracy_test_total", "accuracy_step_total", "ally_health", "enemy_health", "ag_0_same_a_p", "ag_0_same_a_p_test", "return_test", "win_test", "ally_health_test", "enemy_health_test", "loss_dis", "loss_ant"]

# plot_types = ["return", "win", "accuracy_train_total", "accuracy_test_total", "accuracy_step_total", "ally_health", "enemy_health", "ag_0_same_a_p", "ag_0_same_a_p_test", "return_test", "win_test", "ally_health_test", "enemy_health_test",]

# plot_types = ["return", "win", "ally_health", "enemy_health", "ag_0_same_a_p", "ag_0_same_a_p_test", "return_test", "win_test", "ally_health_test", "enemy_health_test",]

plot_types = ["win"]
# plot_types = ["ag_0_same_a_p_test"]
# plot_types = ["win_test"]
# plot_types = ["loss_ant"]
# plot_types = ["enemy_health"]

# plot_types = ["return", "win", "enemy_health"]
# plot_types = ["return", "win", "accuracy_train_total", "accuracy_test_total", "enemy_health"]
# plot_types = ["return", "win", "accuracy_train_total", "accuracy_test_total", "loss_dis", "loss_ant", "enemy_health"]

y_ticks = [0, 22]
x_ticks = [0 , 50001]
plt.rcParams.update({'font.size': 20})
flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71", "#43a16f"]

# %%
for value_name in plot_types:

    if value_name == "return":
        y_range = [-0.1, 22]
        y_ticks = [0, 22]
        x_range = [-10, 40010]
        x_tick_steps = 10000
        y_tick_steps = 5
        legend_location = "lower right"
    elif value_name == "return_test":
        y_range = [-0.1, 22]
        y_ticks = [0, 22]
        x_range = [-10, 4010]
        x_tick_steps = 1000
        y_tick_steps = 5
        legend_location = "lower right"
    elif value_name == "accuracy_train_total":
        y_range = [0.45, 1.01]
        y_ticks = [0, 1.01]
        x_range = [-10, 3010]
        x_tick_steps = 1000
        y_tick_steps = 0.1
        legend_location = "upper right"
    elif value_name == "accuracy_test_total":
        y_range = [0.45, 1.01]
        y_ticks = [0, 1.01]
        x_range = [-10, 2310]
        x_tick_steps = 1000
        y_tick_steps = 0.1
        legend_location = "upper left"
    elif value_name == "accuracy_step_total":
        y_range = [0.45, 1.01]
        y_ticks = [0, 1.01]
        x_range = [-10, 7510]
        x_tick_steps = 2500
        y_tick_steps = 0.1
        legend_location = "upper left"
    elif value_name == "win_test":
        y_range = [-0.01, 1.01]
        y_ticks = [0, 1.01]
        x_range = [-10, 4010]
        x_tick_steps = 1000
        y_tick_steps = 0.5
        legend_location = "upper left"
    elif value_name == "win":
        y_range = [-0.01, 1.01]
        y_ticks = [0, 1.01]
        x_range = [-10, 50010]
        x_tick_steps = 10000
        y_tick_steps = 0.5
        legend_location = "upper left"
    elif value_name == "loss_dis":
        y_range = [-0.01, 5.01]
        y_ticks = [0, 5.01]
        x_range = [-10, 7510]
        x_tick_steps = 2500
        y_tick_steps = 1
        legend_location = "upper left"
    elif value_name == "loss_ant":
        y_range = [-0.01, 5.01]
        y_ticks = [0, 5.01]
        x_range = [-10, 7510]
        x_tick_steps = 2500
        y_tick_steps = 1
        legend_location = "upper left"
    elif value_name == "enemy_health":
        y_range = [-0.01, 1.01]
        y_ticks = [0, 1.01]
        x_range = [-10, 40010]
        x_tick_steps = 10000
        y_tick_steps = 0.2
        legend_location = "upper right"
    elif value_name == "ally_health":
        y_range = [-0.01, 1.01]
        y_ticks = [0, 1.01]
        x_range = [-10, 40010]
        x_tick_steps = 10000
        y_tick_steps = 0.2
        legend_location = "upper right"
    elif value_name == "enemy_health_test":
        y_range = [-0.01, 1.01]
        y_ticks = [0, 1.01]
        x_range = [-10, 4010]
        x_tick_steps = 1000
        y_tick_steps = 0.2
        legend_location = "upper right"
    elif value_name == "ally_health_test":
        y_range = [-0.01, 1.01]
        y_ticks = [0, 1.01]
        x_range = [-10, 4010]
        x_tick_steps = 1000
        y_tick_steps = 0.2
        legend_location = "upper right"
    elif value_name == "ag_0_same_a_p":
        y_range = [-0.01, 1.01]
        y_ticks = [0, 1.01]
        x_range = [-10, 40010]
        x_tick_steps = 10000
        y_tick_steps = 0.2
        legend_location = "upper left"
    elif value_name == "ag_0_same_a_p_test":
        y_range = [-0.01, 1.01]
        y_ticks = [0, 1.01]
        x_range = [-10, 4010]
        x_tick_steps = 1000
        y_tick_steps = 0.5
        legend_location = "upper left"
    else:
        y_range = [-0.1, 22]
        x_range = [-10, 40010]
        x_tick_steps = 10000
        y_tick_steps = None

    epoch_return = None
    df = None

    with open('neptune_auth.json', 'r') as f:
        neptune_auth = json.load(f)
        neptune_auth = DotMap(neptune_auth)

    def get_df_from_neptune(run_id):
        neptune_run = neptune.init(project=neptune_auth.project, api_token=neptune_auth.api_token, mode="read-only", run="AA-{}".format(run_id))
        epoch_return = neptune_run[value_name].fetch_values(include_timestamp=False)['value'][:50000]
        df = pd.DataFrame()
        df["x"] = range(1, len(epoch_return) + 1)
        df[value_name] = epoch_return.rolling(100).mean()

        df = df[df.index % 10 == 0]

        neptune_run.stop()
        return df

    dataframes = []
    for run in runs:
        dataframe = []
        for nep_id in run:
            dataframe.append(get_df_from_neptune(nep_id))
        dataframe = pd.concat(dataframe, ignore_index=True)
        dataframes.append(dataframe)

    current_palette = sns.color_palette(flatui)

    plt_sns = None
    for i, dataframe in enumerate(dataframes):
        plt_sns = sns.lineplot(x="x", y=value_name, data=dataframe, color=current_palette[i], err_style='band')
        # plt_sns = sns.lineplot(x="x", y=value_name, data=dataframe, color=current_palette[i], err_style='band', ci="sd")

    plt_sns.set_xlabel('episode')
    # plt_sns.set_ylabel("loss")
    plt_sns.set_ylabel("win %")
    # plt_sns.set_ylabel("enemy health %")
    # plt_sns.set_ylabel("test win %")
    # plt_sns.set_ylabel("test same action %")

    plt_sns.set_xticks(np.arange(x_ticks[0], x_ticks[1], step=x_tick_steps))
    if y_tick_steps:
        plt_sns.set_yticks(np.arange(y_ticks[0], y_ticks[1], step=y_tick_steps))

    plt_sns.ticklabel_format(style='sci', axis='x', scilimits=(0,0))

    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)

    colors = []
    if len(labels) == 0:
        labels = runs
    for i, label in enumerate(labels):
        colors.append(mpatches.Patch(color=current_palette[i], label='{}'.format(label)))

    leg = plt_sns.legend(handles=colors, labelspacing=0.1, loc=legend_location, fontsize=20)
    leg.set_title(titel)

    plt_sns.set(xlim=(x_range[0], x_range[1]))
    plt_sns.set(ylim=(y_range[0], y_range[1]))
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)
    plt.rcParams.update({'font.size': 20})
    fig = plt_sns.get_figure()

    timestamp = datetime.datetime.now().strftime("%Y_%m_%d_%H_%M_%S")

    plot_dir = os.path.join(os.getcwd(), 'plots')
    if not os.path.exists(plot_dir):
        os.makedirs(plot_dir)
    fig.savefig(os.path.join(plot_dir, 'plot - {}.svg'.format(timestamp)), bbox_inches="tight", format="svg")
    fig.savefig(os.path.join(plot_dir, 'plot - {}.png'.format(timestamp)), dpi=300, bbox_inches="tight")
    fig.clf()
# Out:
# https://app.neptune.ai/arno/master-aa/e/AA-1317
# Remember to stop your run once you’ve finished logging your metadata (https://docs.neptune.ai/api-reference/run#.stop). It will be stopped automatically only when the notebook kernel/interactive console is terminated.
# Shutting down background jobs, please wait a moment...
# Done!
# https://app.neptune.ai/arno/master-aa/e/AA-1318
# Remember to stop your run once you’ve finished logging your metadata (https://docs.neptune.ai/api-reference/run#.stop). It will be stopped automatically only when the notebook kernel/interactive console is terminated.
# Shutting down background jobs, please wait a moment...
# Done!
# https://app.neptune.ai/arno/master-aa/e/AA-1319
# Remember to stop your run once you’ve finished logging your metadata (https://docs.neptune.ai/api-reference/run#.stop). It will be stopped automatically only when the notebook kernel/interactive console is terminated.
# Shutting down background jobs, please wait a moment...
# ...
