# %%
import os
import pandas as pd
import numpy as np
import matplotlib.patches as mpatches
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
import pylab
import neptune
from scipy.interpolate import UnivariateSpline
import matplotlib.gridspec as gridspec

#plt.figure(figsize=(12, 9))

current_palette = sns.color_palette("Set1")

str_dir = '20200223-21-54-23 tr 0 steps 0 mark 100'
value_dir = 'values 20200224-15-42-31'

df_0_00 = pd.read_csv('C:/Users/' + os.environ.get('USERNAME') + '/Desktop/data/' + str_dir + '/evaluation files/' + value_dir + '.csv')

str_dir = '20200223-21-55-36 tr 0 steps 1 mark 100'
value_dir = 'values 20200224-16-46-50'

df_1_00 = pd.read_csv('C:/Users/' + os.environ.get('USERNAME') + '/Desktop/data/' + str_dir + '/evaluation files/' + value_dir + '.csv')

str_dir = '20200223-21-57-09 tr 0 steps 2 mark 100'
value_dir = 'values 20200224-18-26-19'

df_2_00 = pd.read_csv('C:/Users/' + os.environ.get('USERNAME') + '/Desktop/data/' + str_dir + '/evaluation files/' + value_dir + '.csv')

str_dir = '20200224-09-33-10 tr 0 steps 3 mark 100'
value_dir = 'values 20200225-17-49-22'

df_3_00 = pd.read_csv('C:/Users/' + os.environ.get('USERNAME') + '/Desktop/data/' + str_dir + '/evaluation files/' + value_dir + '.csv')

str_dir = '20200224-19-10-33 tr 0 steps 4 mark 100'
value_dir = 'values 20200227-14-44-33'

df_4_00 = pd.read_csv('C:/Users/' + os.environ.get('USERNAME') + '/Desktop/data/' + str_dir + '/evaluation files/' + value_dir + '.csv')

str_dir = '20200224-20-54-07 tr 0 steps 5 mark 100'
value_dir = 'values 20200228-00-33-55'

df_5_00 = pd.read_csv('C:/Users/' + os.environ.get('USERNAME') + '/Desktop/data/' + str_dir + '/evaluation files/' + value_dir + '.csv')

comb_df = pd.concat([df_0_00, df_1_00, df_2_00, df_3_00, df_4_00, df_5_00])

comb_df = comb_df.loc[comb_df.agent == "overall"]

plt = sns.boxplot(x="agent", y="reward", hue="trading_steps", data=comb_df, showmeans=True, palette=current_palette)

#comb_df = comb_df.loc[comb_df.agent == "overall"]
df_0 = comb_df.loc[comb_df.trading_steps == 0]
df_1 = comb_df.loc[comb_df.trading_steps == 1]
df_2 = comb_df.loc[comb_df.trading_steps == 2]
df_3 = comb_df.loc[comb_df.trading_steps == 3]
df_4 = comb_df.loc[comb_df.trading_steps == 4]
df_5 = comb_df.loc[comb_df.trading_steps == 5]

#df_over_no_tr = comb_df.loc[comb_df.agent == "overall"]
#df_over_no_tr = df_over_no_tr.loc[df_over_no_tr.trading_steps == 0]
#df_over_tr = comb_df.loc[comb_df.agent == "overall"]
#df_over_tr = df_over_tr.loc[df_over_tr.trading_steps == 1]
#df_a1 = comb_df.loc[comb_df.agent == "a-1"]
#df_a2 = comb_df.loc[comb_df.agent == "a-2"]

#print(np.mean(df_over_no_tr.reward))

print("0: ", np.mean(df_0.reward))
print("1: ", np.mean(df_1.reward))
print("2: ", np.mean(df_2.reward))
print("3: ", np.mean(df_3.reward))
print("4: ", np.mean(df_4.reward))
print("5: ", np.mean(df_5.reward))

print("0: ", np.median(df_0.reward))
print("1: ", np.median(df_1.reward))
print("2: ", np.median(df_2.reward))
print("3: ", np.median(df_3.reward))
print("4: ", np.median(df_4.reward))
print("5: ", np.median(df_5.reward))

print("1: ", np.mean(df_1.number_trades))
print("2: ", np.mean(df_2.number_trades))
print("3: ", np.mean(df_3.number_trades))
print("4: ", np.mean(df_4.number_trades))
print("5: ", np.mean(df_5.number_trades))

#print(np.mean(df_over_no_tr.number_trades))
#print(np.mean(df_over_tr.number_trades))

labels = [item.get_text() for item in plt.get_xticklabels()]
labels[0] = 'overall'
#labels[1] = 'agent 1'
#labels[2] = 'agent 2'

plt.set_xticklabels(labels)

color_0 = mpatches.Patch(color=current_palette[0], label='no trading')
color_1 = mpatches.Patch(color=current_palette[1], label='1')
color_2 = mpatches.Patch(color=current_palette[2], label='2')
color_3 = mpatches.Patch(color=current_palette[3], label='3')
color_4 = mpatches.Patch(color=current_palette[4], label='4')
color_5 = mpatches.Patch(color=current_palette[5], label='5')

leg = plt.legend(handles=[color_0, color_1, color_2, color_3, color_4, color_5], labelspacing=0.25, loc='lower left')
leg.set_title('offer actions')

plt.set(ylim=(-40, 5))
fig = plt.get_figure()
fig.savefig('tr_mode_0_mark_100_overall.png', dpi=300)

# %%
from dotmap import DotMap
import json
import pandas as pd
import numpy as np
import matplotlib.patches as mpatches
import seaborn as sns
import neptune.new as neptune
import matplotlib.pyplot as plt
import os
import datetime
from matplotlib import rcParams



# box_plot_qmix_algo = [1906, 1907, 1908, 1909, 1910]
# box_plot_vdn_algo = [1911, 1912, 1913, 1914, 1915]
# box_plot_iql_algo = [1916, 1917, 1918, 1919, 1920]
# box_plot_qplex_algo = [1921, 1922, 1923, 1924, 1925]
# box_plot_ow_qmix_algo = [1926, 1927, 1928, 1929, 1932]
# box_plot_qtran_algo = [1931, 1933, 1934, 1935, 1936]
#
# box_obvious_ow_qmix = [1957, 1958, 1959, 1960, 1961]
# box_obvious_qplex = [1962, 1963, 1964, 1965, 1966]
# box_obvious_iql = [1967, 1968, 1969, 1970, 1971]
# box_obvious_vdn = [1972, 1973, 1974, 1975, 1976]
# box_obvious_qmix = [1977, 1978, 1979, 1980, 1981]
# box_obvious_qtran = [1982, 1983, 1984, 1985, 1986]
#
# box_hidden_qmix = [1987, 1988, 1989, 1990, 1991]
# box_hidden_vdn = [1992, 1993, 1994, 1995, 1996]
# box_hidden_iql = [1997, 1998, 1999, 2000, 2001]
# box_hidden_qplex = [2002, 2003, 2004, 2005, 2006]
# box_hidden_ow_qmix = [2007, 2008, 2009, 2010, 2011]
# box_hidden_qtran = [2012, 2013, 2014, 2015, 2016]
#
# box_random_qmix = [2017, 2018, 2019, 2020, 2021]
# box_random_vdn = [2022, 2023, 2024, 2025, 2026]
# box_random_iql = [2027, 2028, 2029, 2030, 2031]
# box_random_qplex = [2032, 2033, 2034, 2035, 2036]
# box_random_ow_qmix = [2037, 2038, 2039, 2040, 2041]
# box_random_qtran = [2042, 2043, 2044, 2045, 2046]

# 3s vs 3z

# algo_qtran_eval = [2524, 2525, 2526, 2527, 2528]
# algo_qmix_eval = [2529, 2530, 2531, 2532, 2533]
# algo_qplex_eval = [2534, 2535, 2536, 2537, 2538]
# algo_vdn_eval = [2539, 2540, 2541, 2542, 2543]
# algo_iql_eval = [2544, 2545, 2546, 2547, 2548]
# algo_ow_qmix_eval = [2549, 2550, 2551, 2552, 2553]
#
# h_qtran_eval = [2797, 2798, 2799, 2800, 2801]
# h_qmix_eval = [2802, 2803, 2804, 2805, 2806]
# h_qplex_eval = [2807, 2808, 2809, 2810, 2811]
# h_vdn_eval = [2812, 2813, 2814, 2815, 2816]
# h_iql_eval = [2817, 2818, 2819, 2820, 2821]
# h_ow_qmix_eval = [2822, 2823, 2824, 2825, 2826]
#
# obv_qtran_eval = [2827, 2828, 2829, 2830, 2831]
# obv_qmix_eval = [2832, 2833, 2834, 2835, 2836]
# obv_qplex_eval = [2837, 2838, 2839, 2840, 2841]
# obv_vdn_eval = [2842, 2843, 2844, 2845, 2846]
# obv_iql_eval = [2847, 2848, 2849, 2850, 2851]
# obv_ow_qmix_eval = [2852, 2853, 2854, 2855, 2856]
#
# random_qtran_eval = [3147, 3148, 3149, 3150, 3151]
# random_qmix_eval = [3152, 3153, 3154, 3155, 3156]
# random_qplex_eval = [3157, 3158, 3159, 3160, 3161]
# random_vdn_eval = [3162, 3163, 3164, 3165, 3166]
# random_iql_eval = [3167, 3168, 3169, 3170, 3171]
# random_ow_qmix_eval = [3172, 3173, 3174, 3175, 3176]

# 5m vs 6m

# algo_qtran_eval = [2494, 2495, 2496, 2497, 2498]
# algo_qmix_eval = [2499, 2500, 2501, 2502, 2503]
# algo_qplex_eval = [2504, 2505, 2506, 2507, 2508]
# algo_vdn_eval = [2509, 2510, 2511, 2512, 2513]
# algo_iql_eval = [2514, 2515, 2516, 2517, 2518]
# algo_ow_qmix_eval = [2519, 2520, 2521, 2522, 2523]
#
# h_qtran_eval = [2857, 2858, 2859, 2860, 2861]
# h_qmix_eval = [2862, 2863, 2864, 2865, 2866]
# h_qplex_eval = [2867, 2868, 2869, 2870, 2871]
# h_vdn_eval = [2872, 2873, 2874, 2875, 2876]
# h_iql_eval = [2877, 2878, 2879, 2880, 2881]
# h_ow_qmix_eval = [2882, 2883, 2884, 2885, 2886]
#
# obv_qtran_eval = [2887, 2888, 2889, 2890, 2891]
# obv_qmix_eval = [2892, 2893, 2894, 2895, 2896]
# obv_qplex_eval = [2897, 2898, 2899, 2900, 2901]
# obv_vdn_eval = [2902, 2903, 2904, 2905, 2906]
# obv_iql_eval = [2907, 2908, 2909, 2910, 2911]
# obv_ow_qmix_eval = [2912, 2913, 2914, 2915, 2916]
#
# random_qtran_eval = [2350, 2351, 2352, 2353, 2354]
# random_qmix_eval = [2355, 2356, 2357, 2358, 2359]
# random_qplex_eval = [2360, 2361, 2362, 2363, 2364]
# random_vdn_eval = [2365, 2366, 2367, 2368, 2369]
# random_iql_eval = [2370, 2371, 2372, 2373, 2374]
# random_ow_qmix_eval = [2375, 2376, 2377, 2378, 2379]


# MMM

algo_qtran_eval = [3040, 3041, 3042, 3043, 3044]
algo_qmix_eval = [3045, 3046, 3047, 3048, 3049]
algo_qplex_eval = [3050, 3051, 3052, 3053, 3054]
algo_vdn_eval = [3055, 3056, 3057, 3058, 3059]
algo_iql_eval = [3060, 3061, 3062, 3063, 3064]
algo_ow_qmix_eval = [3065, 3066, 3067, 3068, 3069]

h_qtran_eval = [3070, 3071, 3072, 3073, 3074]
h_qmix_eval = [3075, 3076, 3077, 3078, 3085]
h_qplex_eval = [3080, 3081, 3082, 3083, 3084]
h_vdn_eval = [3086, 3087, 3088, 3089, 3090]
h_iql_eval = [3091, 3092, 3093, 3094, 3095]
h_ow_qmix_eval = [3096, 3097, 3098, 3099, 3100]

obv_qtran_eval = [3101, 3102, 3103, 3104, 3105]
obv_qmix_eval = [3106, 3107, 3108, 3109, 3110]
obv_qplex_eval = [3111, 3112, 3113, 3114, 3115]
obv_vdn_eval = [3116, 3117, 3118, 3119, 3120]
obv_iql_eval = [3121, 3122, 3123, 3124, 3125]
obv_ow_qmix_eval = [3126, 3127, 3128, 3129, 3130]

random_qtran_eval = [3010, 3011, 3012, 3013, 3019]
random_qmix_eval = [3014, 3015, 3016, 3017, 3018]
random_qplex_eval = [3020, 3021, 3022, 3023, 3024]
random_vdn_eval = [3025, 3026, 3027, 3028, 3029]
random_iql_eval = [3030, 3031, 3032, 3033, 3034]
random_ow_qmix_eval = [3035, 3036, 3037, 3038, 3039]








runs = [algo_qtran_eval, h_qtran_eval, obv_qtran_eval, random_qtran_eval,
        algo_qmix_eval, h_qmix_eval, obv_qmix_eval, random_qmix_eval,
        algo_qplex_eval, h_qplex_eval, obv_qplex_eval, random_qplex_eval,
        algo_vdn_eval, h_vdn_eval, obv_vdn_eval, random_vdn_eval,
        algo_iql_eval, h_iql_eval, obv_iql_eval, random_iql_eval,
        algo_ow_qmix_eval, h_ow_qmix_eval, obv_ow_qmix_eval, random_ow_qmix_eval]
plot_x = ["QTRAN", "QTRAN", "QTRAN", "QTRAN",
          "QMIX", "QMIX", "QMIX", "QMIX",
          "QPLEX", "QPLEX", "QPLEX", "QPLEX",
          "VDN", "VDN", "VDN", "VDN",
          "IQL", "IQL", "IQL", "IQL",
          "OW-QMIX", "OW-QMIX", "OW-QMIX", "OW-QMIX",]


titel = ""

labels = ["Protagonist", "ISAAC Invader", "Naive Invader", "Random Invader"]

# runs = [box_hidden_qmix, box_random_qmix, box_obvious_qmix,
#         box_hidden_vdn, box_random_vdn, box_obvious_vdn,
#         box_hidden_iql, box_random_iql, box_obvious_iql,
#         box_hidden_qplex, box_random_qplex, box_obvious_qplex,
#         box_hidden_ow_qmix, box_random_ow_qmix, box_obvious_ow_qmix,
#         box_hidden_qtran, box_random_qtran, box_obvious_qtran]
# plot_x = ["QMIX", "QMIX", "QMIX",
#           "VDN", "VDN", "VDN",
#           "IQL", "IQL", "IQL",
#           "QPLEX", "QPLEX", "QPLEX",
#           "OW-QMIX", "OW-QMIX", "OW-QMIX",
#           "QTRAN", "QTRAN", "QTRAN"]


# runs = [box_plot_qmix_algo, box_hidden_qmix, box_random_qmix, box_obvious_qmix,
#         box_plot_vdn_algo, box_hidden_vdn, box_random_vdn, box_obvious_vdn,
#         box_plot_iql_algo, box_hidden_iql, box_random_iql, box_obvious_iql,
#         box_plot_qplex_algo, box_hidden_qplex, box_random_qplex, box_obvious_qplex,
#         box_plot_ow_qmix_algo, box_hidden_ow_qmix, box_random_ow_qmix, box_obvious_ow_qmix,
#         box_plot_qtran_algo, box_hidden_qtran, box_random_qtran, box_obvious_qtran]
# plot_x = ["QMIX", "QMIX", "QMIX", "QMIX",
#           "VDN", "VDN", "VDN", "VDN",
#           "IQL", "IQL", "IQL", "IQL",
#           "QPLEX", "QPLEX", "QPLEX", "QPLEX",
#           "OW-QMIX", "OW-QMIX", "OW-QMIX", "OW-QMIX",
#           "QTRAN", "QTRAN", "QTRAN", "QTRAN"]

# runs = [box_plot_qmix_algo, box_plot_qmix_hidden, box_plot_qmix_random]
# plot_x = ["QMIX", "QMIX", "QMIX"]

legend_location = "lower left"

# plot_types = ["enemy_health"]

# plot_types = ["ag_0_same_a_p"]

# plot_types = ["return", "win", "ally_health", "enemy_health"]

plot_types = ["ag_0_same_a_p"]
# plot_types = ["win"]

# plot_types = ["return"]
# plot_types = ["return", "win", "accuracy_train_total", "accuracy_test_total", "enemy_health"]
# plot_types = ["return", "win", "accuracy_train_total", "accuracy_test_total", "loss_dis", "loss_ant", "enemy_health"]

plt.rcParams.update({'font.size': 20})
labels_titel = labels * 100
rcParams['figure.figsize'] = 12, 4
flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71", "#43a16f"]

# %%
for value_name in plot_types:

    # if value_name == "enemy_health":
    #     legend_location = "upper left"

    # if value_name == "return":
    #     y_range = [-0.1, 22]
    #     x_range = [-10, 40000]
    #     x_tick_steps = 10000
    #     legend_location = "lower right"
    # elif value_name == "accuracy_train_total":
    #     y_range = [0.45, 1.01]
    #     x_range = [-10, 3010]
    #     x_tick_steps = 1000
    #     legend_location = "upper left"
    # elif value_name == "accuracy_test_total":
    #     y_range = [0.45, 1.01]
    #     x_range = [-10, 4010]
    #     x_tick_steps = 1000
    #     legend_location = "upper left"
    # elif value_name == "win":
    #     y_range = [-0.01, 1.01]
    #     x_range = [-10, 40000]
    #     x_tick_steps = 10000
    #     legend_location = "upper left"
    # elif value_name == "loss_dis":
    #     y_range = [-0.01, 5.01]
    #     x_range = [-10, 460]
    #     x_tick_steps = 100
    #     legend_location = "upper left"
    # elif value_name == "loss_ant":
    #     y_range = [-0.01, 5.01]
    #     x_range = [-10, 460]
    #     x_tick_steps = 100
    #     legend_location = "upper left"
    # elif value_name == "enemy_health":
    #     y_range = [-0.01, 1.01]
    #     x_range = [-10, 40000]
    #     x_tick_steps = 10000
    #     legend_location = "upper right"
    # else:
    #     y_range = [-0.1, 22]
    #     x_range = [-10, 40000]
    #     x_tick_steps = 10000

    epoch_return = None
    df = None

    with open('neptune_auth.json', 'r') as f:
        neptune_auth = json.load(f)
        neptune_auth = DotMap(neptune_auth)

    def get_df_from_neptune(run_id):
        neptune_run = neptune.init(project=neptune_auth.project, api_token=neptune_auth.api_token, mode="read-only", run="AA-{}".format(run_id))
        if value_name == "ag_0_same_a_p":
            df = pd.DataFrame()
            try:
                epoch_return = neptune_run[value_name].fetch_values(include_timestamp=False)['value']
                df = pd.DataFrame()
                df["x"] = range(1, len(epoch_return) + 1)
                df[value_name] = epoch_return

            except:
                df["x"] = range(1, 1001)
                df[value_name] = 1
        else:
            epoch_return = neptune_run[value_name].fetch_values(include_timestamp=False)['value']
            df = pd.DataFrame()
            df["x"] = range(1, len(epoch_return) + 1)
            if value_name == "win":
                df[value_name] = epoch_return.rolling(100).mean()
            else:
                df[value_name] = epoch_return

        df = df[df.index <= 1000]

        neptune_run.stop()
        return df

    dataframes = []
    for run, label, p_x in zip(runs, labels_titel, plot_x):
        dataframe = []
        for nep_id in run:
            dataframe.append(get_df_from_neptune(nep_id))
        dataframe = pd.concat(dataframe, ignore_index=True)
        dataframe["hue"] = label
        dataframe["algorithm"] = p_x
        dataframes.append(dataframe)

    combined_dataframe = pd.concat(dataframes, ignore_index=True)

    current_palette = sns.color_palette(flatui)

    # plt_sns = sns.boxplot(x="x_bins", y=value_name, hue="hue", data=combined_dataframe, showmeans=True, palette=current_palette)

    plt_sns = sns.boxplot(x="algorithm", y=value_name, hue="hue", data=combined_dataframe, showmeans=True, fliersize=1, palette=current_palette)

    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)
    plt_sns.set_xlabel('algorithm')
    # plt_sns.set_ylabel("win %")
    plt_sns.set_ylabel("same action %")

    colors = []
    if len(labels) == 0:
        labels = runs
    for i, label in enumerate(labels):
        colors.append(mpatches.Patch(color=current_palette[i], label='{}'.format(label)))

    leg = plt_sns.legend(handles=colors, labelspacing=0.1, loc=legend_location, fontsize=20)
    plt.rcParams.update({'font.size': 20})
    leg.set_title(titel)

    plt_sns.grid(False)
    fig = plt_sns.get_figure()
    timestamp = datetime.datetime.now().strftime("%Y_%m_%d_%H_%M_%S")

    plot_dir = os.path.join(os.getcwd(), 'plots')
    if not os.path.exists(plot_dir):
        os.makedirs(plot_dir)
    fig.savefig(os.path.join(plot_dir, 'plot - {}.svg'.format(timestamp)), bbox_inches="tight", format="svg")
    fig.savefig(os.path.join(plot_dir, 'plot - {}.png'.format(timestamp)), dpi=300, bbox_inches="tight")
    fig.clf()
# Out:
# https://app.neptune.ai/arno/master-aa/e/AA-3040
# Remember to stop your run once you’ve finished logging your metadata (https://docs.neptune.ai/api-reference/run#.stop). It will be stopped automatically only when the notebook kernel/interactive console is terminated.
# Shutting down background jobs, please wait a moment...
# Done!
# https://app.neptune.ai/arno/master-aa/e/AA-3041
# Remember to stop your run once you’ve finished logging your metadata (https://docs.neptune.ai/api-reference/run#.stop). It will be stopped automatically only when the notebook kernel/interactive console is terminated.
# Shutting down background jobs, please wait a moment...
# Done!
# https://app.neptune.ai/arno/master-aa/e/AA-3042
# Remember to stop your run once you’ve finished logging your metadata (https://docs.neptune.ai/api-reference/run#.stop). It will be stopped automatically only when the notebook kernel/interactive console is terminated.
# Shutting down background jobs, please wait a moment...
# ...
