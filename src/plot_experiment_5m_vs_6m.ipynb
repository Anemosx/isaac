# %%
from dotmap import DotMap
import json
import pandas as pd
import numpy as np
import matplotlib.patches as mpatches
import seaborn as sns
import matplotlib.pyplot as plt
import neptune.new as neptune
import os
import datetime

"""
High quality plots for evaluation.

author(s): Arnold Unterauer
"""




###########################

old_algo_qmix = [1561, 1562, 1563, 1564, 1565]
old_algo_qtran = [1566, 1567, 1568, 1569, 1570]
old_algo_iql = [1571, 1572, 1573, 1574, 1575]
old_algo_vdn = [1576, 1577, 1578, 1579, 1580]
old_algo_qplex = [1586, 1587, 1588, 1589, 1590]
old_algo_ow_qmix = [1591, 1592, 1593, 1594, 1595]

broken_algo_qmix = [1606, 1607, 1608, 1609, 1610]
broken_algo_qtran = [1611, 1612, 1613, 1614, 1615]
broken_algo_iql = [1616, 1617, 1618, 1619, 1620]
broken_algo_vdn = [1621, 1622, 1623, 1624, 1625]
broken_algo_qplex = [1626, 1627, 1628, 1629, 1630]
broken_algo_ow_qmix = [1631, 1632, 1633, 1634, 1635]

qtran_hidden = [1691, 1692, 1693, 1694, 1695]
qmix_hidden = [1696, 1697, 1698, 1699, 1700]
qtran_obvious = [1701, 1702, 1703, 1704, 1705]

qtran_random = [1706, 1707, 1708, 1709, 1710]
qmix_random = [1711, 1712, 1713, 1714, 1715]
vdn_random = [1716, 1717, 1718, 1719, 1720]
iql_random = [1721, 1722, 1723, 1724, 1725]
qplex_random = [1756, 1757, 1758, 1759, 1760]
ow_qmix_random = [1761, 1762, 1763, 1764, 1765]

qtran_tr_20 = [1726, 1727, 1728, 1729, 1730]
qtran_tr_20_step_20 = [1731, 1732, 1733, 1734, 1735]
qtran_tr_30_step_30 = [1736, 1737, 1738, 1739, 1740]

qtran_tr_10 = [1741, 1742, 1743, 1744, 1745]
qtran_tr_15 = [1746, 1747, 1748, 1749, 1750]
qtran_with_delay = [1751, 1752, 1753, 1754, 1755]

failed_qmix_tr_10 = [1766, 1767, 1768, 1769, 1770]

eval_qtran = [1771, 1772, 1773, 1774, 1775]
eval_qmix = [1776, 1777, 1778, 1779, 1780]
eval_iql = [1781, 1782, 1783, 1784, 1785]
eval_vdn = [1786, 1787, 1788, 1789, 1790]
eval_qplex = [1791, 1792, 1793, 1794, 1795]
eval_ow_qmix = [1796, 1797, 1798, 1799, 1800]

qmix_compare_actions_tr_5 = [1801, 1802, 1803, 1804, 1805]
qmix_compare_actions_tr_10 = [1806, 1807, 1808, 1809, 1810]
qmix_compare_actions_tr_5_timed = [1811, 1812, 1813, 1814, 1815]

qmix_antagonist_loss_0_2 = [1816, 1817, 1818, 1819, 1820]
qmix_obvious = [1821, 1822, 1823, 1824, 1825]
qmix_random_1 = [1826, 1827, 1828, 1829, 1830]

qtran_comp_tr_5 = [2067, 2068, 2069, 2070, 2071]
qtran_comp_tr_10 = [2072, 2073, 2074, 2075, 2076]
qtran_comp_tr_20 = [2077, 2078, 2079, 2080, 2081]
qtran_comp_tr_15 = [2082, 2083, 2084, 2085, 2086]
qtran_comp_tr_25 = [2087, 2088, 2089, 2090, 2091]
qtran_comp_tr_30 = [2092, 2093, 2094, 2095, 2096]

qtran_comp_step_3 = [2097, 2098, 2099, 2100, 2101]
qtran_comp_step_8 = [2102, 2103, 2104, 2105, 2106]
qtran_comp_step_15 = [2107, 2108, 2109, 2110, 2111]

obvious_qmix_old = [2142, 2143, 2144, 2145, 2146]
obvious_qtran_old = [2147, 2148, 2149, 2150, 2151]
obvious_qplex_old = [2152, 2153, 2154, 2155, 2156]
obvious_vdn_old = [2157, 2158, 2159, 2160, 2161]
obvious_iql_old = [2162, 2163, 2164, 2165, 2166]
obvious_ow_qmix_old = [2167, 2168, 2169, 2170, 2171]


only_imitate_qmix = [2917, 2918, 2919, 2920, 2921]




algo_qtran = [1651, 1652, 1653, 1654, 1655]
algo_qmix = [1646, 1647, 1648, 1649, 1650]
algo_qplex = [1666, 1667, 1668, 1669, 1670]
algo_vdn = [1661, 1662, 1663, 1664, 1665]
algo_iql = [1656, 1657, 1658, 1659, 1660]
algo_ow_qmix = [1671, 1672, 1673, 1674, 1675]

hidden_qtran = [2284, 2285, 2286, 2287, 2288]
hidden_qmix = [2289, 2290, 2291, 2292, 2293]
hidden_qplex = [2294, 2295, 2296, 2298, 2299]
hidden_vdn = [2300, 2301, 2302, 2303, 2304]
hidden_iql = [2305, 2306, 2307, 2308, 2309]
hidden_ow_qmix = [2315, 2316, 2317, 2318, 2319]

obvious_qtran = [2320, 2321, 2322, 2323, 2324]
obvious_qmix = [2325, 2326, 2327, 2328, 2329]
obvious_qplex = [2330, 2331, 2332, 2333, 2334]
obvious_vdn = [2335, 2336, 2337, 2338, 2339]
obvious_iql = [2340, 2341, 2342, 2343, 2344]
obvious_ow_qmix = [2345, 2346, 2347, 2348, 2349]

random_qtran = [2350, 2351, 2352, 2353, 2354]
random_qmix = [2355, 2356, 2357, 2358, 2359]
random_qplex = [2360, 2361, 2362, 2363, 2364]
random_vdn = [2365, 2366, 2367, 2368, 2369]
random_iql = [2370, 2371, 2372, 2373, 2374]
random_ow_qmix = [2375, 2376, 2377, 2378, 2379]






tr_1_qmix = [2459, 2460, 2461, 2462, 2463]
tr_3_qmix = [2464, 2465, 2466, 2467, 2468]
tr_5_qmix = [2289, 2290, 2291, 2292, 2293]
tr_10_qmix = [2469, 2470, 2471, 2472, 2473]
tr_15_qmix = [2474, 2475, 2476, 2477, 2478]
tr_20_qmix = [2479, 2480, 2481, 2482, 2483]
tr_30_qmix = [2484, 2485, 2486, 2487, 2488]
tr_50_qmix = [2489, 2490, 2491, 2492, 2493]

algo_qtran_eval = [2494, 2495, 2496, 2497, 2498]
algo_qmix_eval = [2499, 2500, 2501, 2502, 2503]
algo_qplex_eval = [2504, 2505, 2506, 2507, 2508]
algo_vdn_eval = [2509, 2510, 2511, 2512, 2513]
algo_iql_eval = [2514, 2515, 2516, 2517, 2518]
algo_ow_qmix_eval = [2519, 2520, 2521, 2522, 2523]




h_qtran = [2617, 2618, 2619, 2620, 2621]
h_qmix = [2627, 2623, 2624, 2625, 2626]
h_qplex = [2628, 2629, 2630, 2631, 2632]
h_vdn = [2633, 2634, 2635, 2636, 2637]
h_iql = [2638, 2639, 2640, 2641, 2642]
h_ow_qmix = [2643, 2644, 2645, 2646, 2647]

obv_qtran = [2648, 2649, 2650, 2651, 2652]
obv_qmix = [2653, 2654, 2655, 2656, 2657]
obv_qplex = [2658, 2659, 2660, 2661, 2662]
obv_vdn = [2663, 2664, 2665, 2666, 2667]
obv_iql = [2668, 2669, 2670, 2671, 2672]
obv_ow_qmix = [2673, 2674, 2675, 2676, 2677]





qmix_tr_1 = [2746, 2747, 2748, 2749, 2750]
qmix_tr_3 = [2751, 2752, 2753, 2754, 2755]
qmix_tr_10 = [2756, 2758, 2759, 2760, 2761]
qmix_tr_15 = [2762, 2763, 2764, 2765, 2766]
qmix_tr_20 = [2767, 2768, 2769, 2770, 2771]
qmix_tr_25 = [2772, 2773, 2774, 2775, 2776]
qmix_tr_30 = [2777, 2778, 2779, 2780, 2781]
qmix_tr_50 = [2782, 2783, 2784, 2785, 2786]







h_qtran_eval = [2857, 2858, 2859, 2860, 2861]
h_qmix_eval = [2862, 2863, 2864, 2865, 2866]
h_qplex_eval = [2867, 2868, 2869, 2870, 2871]
h_vdn_eval = [2872, 2873, 2874, 2875, 2876]
h_iql_eval = [2877, 2878, 2879, 2880, 2881]
h_ow_qmix_eval = [2882, 2883, 2884, 2885, 2886]


obv_qtran_eval = [2887, 2888, 2889, 2890, 2891]
obv_qmix_eval = [2892, 2893, 2894, 2895, 2896]
obv_qplex_eval = [2897, 2898, 2899, 2900, 2901]
obv_vdn_eval = [2902, 2903, 2904, 2905, 2906]
obv_iql_eval = [2907, 2908, 2909, 2910, 2911]
obv_ow_qmix_eval = [2912, 2913, 2914, 2915, 2916]













plex_th_off = [3182, 3183, 3184, 3185, 3186]
plex_th_0_0 = [3177, 3178, 3179, 3180, 3181]
plex_th_0_001 = [2922, 2923, 2924, 2925, 2926]
plex_th_0_01 = [2927, 2928, 2929, 2930, 2931]
plex_th_0_1 = [2932, 2933, 2934, 2935, 2936]
plex_th_1_0 = [2628, 2629, 2630, 2631, 2632]
plex_th_10_0 = [2937, 2938, 2939, 2940, 2941]
plex_th_100_0 = [2942, 2943, 2944, 2945, 2946]








h_qmix_same_30_eval = [3192, 3193, 3194, 3195, 3196]
h_qmix_same_40_eval = [3197, 3198, 3199, 3200, 3201]
h_qmix_same_50_eval = [3202, 3203, 3204, 3205, 3206]
h_qmix_same_60_eval = [3207, 3208, 3209, 3210, 3211]
h_qmix_same_70_eval = [3212, 3213, 3214, 3215, 3216]


plex_th_off_eval = [3217, 3218, 3219, 3220, 3221]
plex_th_0_0_eval = [3222, 3223, 3224, 3225, 3226]
plex_th_0_001_eval = [3227, 3228, 3229, 3230, 3231]
plex_th_0_01_eval = [3232, 3233, 3234, 3235, 3236]
plex_th_0_1_eval = [3237, 3238, 3239, 3240, 3241]
plex_th_1_0_eval = [3242, 3243, 3244, 3245, 3246]
plex_th_10_0_eval = [3247, 3248, 3249, 3250, 3251]
plex_th_100_0_eval = [3252, 3253, 3254, 3255, 3256]







titel = ""


runs = [h_qtran, h_qmix, h_qplex, h_vdn, h_iql, h_ow_qmix]
# runs = [obv_qtran, obv_qmix, obv_qplex, obv_vdn, obv_iql, obv_ow_qmix]
# runs = [algo_qtran, algo_qmix, algo_qplex, algo_vdn, algo_iql, algo_ow_qmix]
labels = ["QTRAN", "QMIX", "QPLEX", "VDN", "IQL", "OW-QMIX"]


# runs = [plex_th_off, plex_th_0_0, plex_th_0_001, plex_th_0_01, plex_th_0_1, plex_th_1_0, plex_th_10_0, plex_th_100_0]
# labels = ["Without $T_{bs}$", "$T_{bs}$ = 0.0", "$T_{bs}$ = 0.001", "$T_{bs}$ = 0.01", "$T_{bs}$ = 0.1", "$T_{bs}$ = 1.0", "$T_{bs}$ = 10.0", "$T_{bs}$ = 100.0"]

# runs = [qmix_tr_1, qmix_tr_3, h_qmix, qmix_tr_10, qmix_tr_15, qmix_tr_20, qmix_tr_25, qmix_tr_30, qmix_tr_50]
# labels = ["$Sd_{bir}$ = 1:1", "$Sd_{bir}$ = 3:1", "$Sd_{bir}$ = 5:1", "$Sd_{bir}$ = 10:1", "$Sd_{bir}$ = 15:1", "$Sd_{bir}$ = 20:1", "$Sd_{bir}$ = 25:1", "$Sd_{bir}$ = 30:1", "$Sd_{bir}$ = 50:1"]


# labels = ["Ratio 1:1", "Ratio 1:3", "Ratio 1:5", "Ratio 1:10", "Ratio 1:15", "Ratio 1:20", "Ratio 1:30", "Ratio 1:50"]

# labels = ["No Substitution", "Hidden Attacker", "Random Agent", "Obvious Attacker"]




# runs = [hidden_qtran, hidden_qmix, hidden_qplex, hidden_vdn, hidden_iql, hidden_ow_qmix]

# runs = [h_qtran, h_qmix, h_qplex, h_vdn, h_iql, h_ow_qmix]
#
# labels = ["QTRAN", "QMIX", "QPLEX", "VDN", "IQL", "OW-QMIX"]


# runs = [qtran_comp_tr_5, qtran_comp_tr_10, qtran_comp_tr_15, qtran_comp_tr_20, qtran_comp_tr_25, qtran_comp_tr_30]
# labels = ["TR 5", "TR 10", "TR 15", "TR 20", "TR 25", "TR 30"]

# runs = [qtran_hidden, qtran_tr_10, qtran_tr_15, qtran_tr_20]
# labels = ["TR 5", "TR 10", "TR 15", "TR 20"]

# runs = [qmix_compare_actions_tr_10, qmix_obvious, qmix_random_1]
# labels = ["Hidden Attacker", "Obvious", "Random"]

# runs = [eval_qmix, eval_vdn, eval_iql, eval_qplex, eval_ow_qmix, eval_qtran]
# labels = ["QMIX", "VDN", "IQL", "QPLEX", "OW-QMIX", "QTRAN"]

# runs = [algo_qmix, algo_vdn, algo_iql, algo_qplex, algo_ow_qmix, algo_qtran]
# labels = ["QMIX", "VDN", "IQL", "QPLEX", "OW-QMIX", "QTRAN"]



legend_location = "upper left"


plot_types = ["return", "win", "accuracy_train_total", "accuracy_test_total", "accuracy_step_total", "ally_health", "enemy_health", "ag_0_same_a_p", "ag_0_same_a_p_test", "return_test", "win_test", "ally_health_test", "enemy_health_test", "loss_dis", "loss_ant"]

# plot_types = ["win"]
# plot_types = ["loss_ant"]

# plot_types = ["loss_dis", "loss_ant"]

# plot_types = ["win_test"]
# plot_types = ["accuracy_test_total"]
# plot_types = ["accuracy_step_total"]

# plot_types = ["ag_0_same_a_p_test"]
# plot_types = ["win_test", "ag_0_same_a_p_test", "loss_ant", "accuracy_test_total"]

# plot_types = ["ag_0_same_a_p_test", "return_test", "win_test",]

# plot_types = ["return_test"]
# plot_types = ["return", "win", "accuracy_train_total", "accuracy_test_total", "accuracy_step_total", "ally_health", "enemy_health", "ag_0_same_a_p", "ag_0_same_a_p_test", "return_test", "win_test",]
# plot_types = ["return", "win", "accuracy_train_total", "accuracy_test_total", "loss_dis", "loss_ant"]
# plot_types = ["return", "win", "ally_health", "enemy_health", "accuracy_train_total", "accuracy_test_total", "accuracy_step_total",  "ag_0_same_a_p"]
# plot_types = ["return", "win", "ally_health", "enemy_health"]

# plot_types = ["accuracy_train_total", "accuracy_test_total", "accuracy_step_total", "ally_health", "enemy_health"]

x_ticks = [0 , 80001]
plt.rcParams.update({'font.size': 20})
plt.rcParams.update({'mathtext.default':  'regular' })

flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71", "#43a16f", "#ffa35a", "#ffbaff"]

# %%
for value_name in plot_types:

    if value_name == "return":
        y_range = [-0.1, 22]
        x_range = [-10, 20010]
        x_tick_steps = 5000
        y_ticks = [0, 22]
        y_tick_steps = 5
        legend_location = "upper left"
    elif value_name == "return_test":
        y_range = [-0.1, 22]
        x_range = [-10, 2010]
        x_tick_steps = 500
        y_ticks = [0, 22]
        y_tick_steps = 5
        legend_location = "upper left"
    elif value_name == "accuracy_train_total":
        y_range = [0.45, 1.01]
        x_range = [-10, 3760]
        x_tick_steps = 1000
        y_ticks = [0, 1.01]
        y_tick_steps = 0.1
        legend_location = "upper left"
    elif value_name == "accuracy_test_total":
        y_range = [0.45, 1.01]
        x_range = [-10, 1160]
        x_tick_steps = 500
        y_ticks = [0, 1.01]
        y_tick_steps = 0.1
        legend_location = "upper left"
    elif value_name == "accuracy_step_total":
        y_range = [0.45, 1.01]
        x_range = [-10, 3760]
        x_tick_steps = 1000
        y_ticks = [0, 1.01]
        y_tick_steps = 0.1
    elif value_name == "win":
        y_range = [-0.01, 1.01]
        x_range = [-10, 80010]
        x_tick_steps = 20000
        y_ticks = [0, 1.01]
        y_tick_steps = 0.5
        legend_location = "upper left"
    elif value_name == "win_test":
        y_range = [-0.01, 1.01]
        x_range = [-10, 2010]
        x_tick_steps = 500
        y_ticks = [0, 1.01]
        y_tick_steps = 0.5
        legend_location = "upper left"
    elif value_name == "loss_dis":
        y_range = [-0.01, 5.01]
        x_range = [-10, 3760]
        x_tick_steps = 1000
        y_ticks = [0, 5.01]
        y_tick_steps = 1
        legend_location = "upper left"
    elif value_name == "loss_ant":
        y_range = [-0.01, 3.01]
        x_range = [-10, 3760]
        x_tick_steps = 1000
        y_ticks = [0, 5.01]
        y_tick_steps = 1
        legend_location = "upper left"
    elif value_name == "enemy_health":
        y_range = [-0.01, 1.01]
        x_range = [-10, 20010]
        x_tick_steps = 5000
        y_ticks = [0, 1.01]
        y_tick_steps = 0.2
        legend_location = "upper left"
    elif value_name == "enemy_health_test":
        y_range = [-0.01, 1.01]
        x_range = [-10, 2010]
        x_tick_steps = 1000
        y_ticks = [0, 1.01]
        y_tick_steps = 0.2
        legend_location = "upper left"
    elif value_name == "ag_0_same_a_p":
        y_range = [-0.01, 1.01]
        x_range = [-10, 20010]
        x_tick_steps = 5000
        y_ticks = [0, 1.01]
        y_tick_steps = 0.2
        legend_location = "upper left"
    elif value_name == "ag_0_same_a_p_test":
        y_range = [-0.01, 1.01]
        x_range = [-10, 2010]
        x_tick_steps = 500
        y_ticks = [0, 1.01]
        y_tick_steps = 0.5
        legend_location = "upper left"
    elif value_name == "ally_health":
        y_range = [-0.01, 1.01]
        x_range = [-10, 20010]
        x_tick_steps = 5000
        y_ticks = [0, 1.01]
        y_tick_steps = 0.2
        legend_location = "upper right"
    elif value_name == "ally_health_test":
        y_range = [-0.01, 1.01]
        x_range = [-10, 2010]
        x_tick_steps = 1000
        y_ticks = [0, 1.01]
        y_tick_steps = 0.2
        legend_location = "upper right"
    else:
        y_tick_steps = None
        y_ticks = [0, 1.01]
        y_range = [-0.1, 22]
        x_range = [-10, 20010]
        x_tick_steps = 5000

    epoch_return = None
    df = None

    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)

    with open('neptune_auth.json', 'r') as f:
        neptune_auth = json.load(f)
        neptune_auth = DotMap(neptune_auth)

    def get_df_from_neptune(run_id):
        neptune_run = neptune.init(project=neptune_auth.project, api_token=neptune_auth.api_token, mode="read-only", run="AA-{}".format(run_id))
        epoch_return = neptune_run[value_name].fetch_values(include_timestamp=False)['value'][:80000]
        df = pd.DataFrame()
        df["x"] = range(1, len(epoch_return) + 1)
        df[value_name] = epoch_return.rolling(100).mean()

        df = df[df.index % 10 == 0]

        neptune_run.stop()
        return df

    dataframes = []
    for run in runs:
        dataframe = []
        for nep_id in run:
            dataframe.append(get_df_from_neptune(nep_id))
        dataframe = pd.concat(dataframe, ignore_index=True)
        dataframes.append(dataframe)

    current_palette = sns.color_palette(flatui)

    plt_sns = None
    for i, dataframe in enumerate(dataframes):
        # plt_sns = sns.lineplot(x="x", y=value_name, data=dataframe, color=current_palette[i], err_style='band')
        plt_sns = sns.lineplot(x="x", y=value_name, data=dataframe, color=current_palette[i], err_style='band', ci="sd")

    plt_sns.set_xlabel('episode')
    plt_sns.set_ylabel(value_name)
    # plt_sns.set_ylabel("loss")
    # plt_sns.set_ylabel("undiscounted return")
    # plt_sns.set_ylabel("dis test accuracy %")
    # plt_sns.set_ylabel("class test accuracy %")
    # plt_sns.set_ylabel("win %")
    # plt_sns.set_ylabel("test win %")
    # plt_sns.set_ylabel("test same action %")
    plt_sns.set_xticks(np.arange(x_ticks[0], x_ticks[1], step=x_tick_steps))
    if y_tick_steps:
        plt_sns.set_yticks(np.arange(y_ticks[0], y_ticks[1], step=y_tick_steps))

    plt_sns.ticklabel_format(style='sci', axis='x', scilimits=(0,0))

    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)

    colors = []
    if len(labels) == 0:
        labels = runs
    for i, label in enumerate(labels):
        colors.append(mpatches.Patch(color=current_palette[i], label='{}'.format(label)))

    leg = plt_sns.legend(handles=colors, labelspacing=0.1, loc=legend_location, fontsize=20)
    leg.set_title(titel)

    plt_sns.set(xlim=(x_range[0], x_range[1]))
    plt_sns.set(ylim=(y_range[0], y_range[1]))
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)
    plt.rcParams.update({'font.size': 20})
    fig = plt_sns.get_figure()

    timestamp = datetime.datetime.now().strftime("%Y_%m_%d_%H_%M_%S")

    plot_dir = os.path.join(os.getcwd(), 'plots')
    if not os.path.exists(plot_dir):
        os.makedirs(plot_dir)
    fig.savefig(os.path.join(plot_dir, 'plot - {}.svg'.format(timestamp)), bbox_inches="tight", format="svg")
    fig.savefig(os.path.join(plot_dir, 'plot - {}.png'.format(timestamp)), dpi=300, bbox_inches="tight")
    fig.clf()
# Out:
# https://app.neptune.ai/arno/master-aa/e/AA-2617
# Remember to stop your run once you’ve finished logging your metadata (https://docs.neptune.ai/api-reference/run#.stop). It will be stopped automatically only when the notebook kernel/interactive console is terminated.
# Shutting down background jobs, please wait a moment...
# Done!
# https://app.neptune.ai/arno/master-aa/e/AA-2618
# Remember to stop your run once you’ve finished logging your metadata (https://docs.neptune.ai/api-reference/run#.stop). It will be stopped automatically only when the notebook kernel/interactive console is terminated.
# Shutting down background jobs, please wait a moment...
# Done!
# https://app.neptune.ai/arno/master-aa/e/AA-2619
# Remember to stop your run once you’ve finished logging your metadata (https://docs.neptune.ai/api-reference/run#.stop). It will be stopped automatically only when the notebook kernel/interactive console is terminated.
# Shutting down background jobs, please wait a moment...
# ...
